# %%
# Data processing
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Time series
from statsmodels.tsa.arima.model import ARIMA

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/crude_oil_daily.csv
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/README.md
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/country_impact.csv
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/war_timeline.csv
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/petrol_prices_comparison.csv
# /kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/pros_cons_analysis.csv

# %%
data_path = "/kaggle/input/datasets/zkskhurram/global-petrol-prices-impact-of-2026-us-iran-war/"

# %%
prices = pd.read_csv(data_path + "petrol_prices_comparison.csv")
crude = pd.read_csv(data_path + "crude_oil_daily.csv")
impact = pd.read_csv(data_path + "country_impact.csv")
timeline = pd.read_csv(data_path + "war_timeline.csv")
pros_cons = pd.read_csv(data_path + "pros_cons_analysis.csv")

# %%
prices.head()
# Out:
#        Country  ISO      Region Currency  Before_War_Price  Mar7_Price   Unit  \
# 0     Pakistan  PAK  South Asia      PKR            266.17      321.17  PKR/L
# 1        India  IND  South Asia      INR             94.77       94.77  INR/L
# 2   Bangladesh  BGD  South Asia      BDT            125.00      130.00  BDT/L
# 3  Afghanistan  AFG  South Asia      AFN             57.00       57.00  AFN/L
# 4        Nepal  NPL  South Asia      NPR            186.00      190.00  NPR/L
#
#    Amount_Change  Pct_Increase     Trend  Before_War_USD  Mar7_USD  \
# 0           55.0         20.66  Increase            0.95      1.15
# 1            0.0          0.00    Stable            1.14      1.14
# 2            5.0          4.00  Increase            1.02      1.06
# 3            0.0          0.00    Stable            0.82      0.82
# 4            4.0          2.15  Increase            1.40      1.43
#
#   Oil_Import_Dep
# 0           High
# 1           High
# 2           High
# 3           High
# 4           High

# %%
print("Prices Dataset Shape:", prices.shape)
print("Crude Dataset Shape:", crude.shape)
print("Impact Dataset Shape:", impact.shape)

prices.info()
# Out:
# Prices Dataset Shape: (14, 13)
# Crude Dataset Shape: (16, 7)
# Impact Dataset Shape: (17, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           14 non-null     object
#  1   ISO               14 non-null     object
#  2   Region            14 non-null     object
#  3   Currency          14 non-null     object
#  4   Before_War_Price  14 non-null     float64
#  5   Mar7_Price        14 non-null     float64
#  6   Unit              14 non-null     object
#  7   Amount_Change     14 non-null     float64
#  8   Pct_Increase      14 non-null     float64
#  9   Trend             14 non-null     object
#  10  Before_War_USD    14 non-null     float64
#  11  Mar7_USD          14 non-null     float64
#  12  Oil_Import_Dep    14 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 1.6+ KB

# %%
prices.isnull().sum()
crude.isnull().sum()
# Out:
# Date                0
# Brent_USD           0
# WTI_USD             0
# Brent_Change_Pct    0
# WTI_Change_Pct      0
# Phase               0
# Strait_Hormuz       0
# dtype: int64

# %%
crude["Date"] = pd.to_datetime(crude["Date"])

crude.head()
# Out:
#         Date  Brent_USD  WTI_USD  Brent_Change_Pct  WTI_Change_Pct  \
# 0 2026-02-16       74.2     70.1              0.00            0.00
# 1 2026-02-17       74.5     70.4              0.40            0.43
# 2 2026-02-18       75.1     71.0              0.81            0.85
# 3 2026-02-19       75.8     71.6              0.93            0.85
# 4 2026-02-20       76.0     71.8              0.26            0.28
#
#           Phase Strait_Hormuz
# 0  Pre-Conflict          Open
# 1  Pre-Conflict          Open
# 2  Pre-Conflict          Open
# 3  Pre-Conflict          Open
# 4  Pre-Conflict          Open

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=prices,
    x="Pct_Increase",
    y="Country"
)

plt.title("Petrol Price Increase by Country")
plt.xlabel("Percentage Increase")
plt.ylabel("Country")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=prices,
    x="Region",
    y="Pct_Increase"
)

plt.title("Petrol Price Increase by Region")

plt.show()

# %%
top_countries = prices.sort_values(
    by="Pct_Increase",
    ascending=False
).head(5)

fig = px.bar(
    top_countries,
    x="Country",
    y="Pct_Increase",
    title="Top 5 Countries with Highest Petrol Price Increase",
    color="Country"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35a0bfa6-d619-4991-92ba-076366ba49c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a0bfa6-d619-4991-92ba-076366ba49c4")) {                    Plotly.newPlot(                        "35a0bfa6-d619-4991-92ba-076366ba49c4",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ePct_Increase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pakistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[20.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ePct_Increase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iran","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Iran","offsetgroup":"Iran","orientation":"v","showlegend":true,"textposition":"auto","x":["Iran"],"xaxis":"x","y":[6.67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ePct_Increase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saudi Arabia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Saudi Arabia","offsetgroup":"Saudi Arabia","orientation":"v","showlegend":true,"textposition":"auto","x":["Saudi Arabia"],"xaxis":"x","y":[6.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ePct_Increase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":["USA"],"xaxis":"x","y":[5.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ePct_Increase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %%
plt.figure(figsize=(10,6))

plt.plot(
    crude["Date"],
    crude["Brent_USD"],
    label="Brent"
)

plt.plot(
    crude["Date"],
    crude["WTI_USD"],
    label="WTI"
)

plt.title("Crude Oil Prices During Conflict")
plt.xlabel("Date")
plt.ylabel("Price (USD)")

plt.legend()

plt.show()

# %%
crude["Brent_Return"] = crude["Brent_USD"].pct_change()

plt.figure(figsize=(10,5))

sns.histplot(
    crude["Brent_Return"],
    bins=10
)

plt.title("Oil Price Volatility Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=prices,
    x="Oil_Import_Dep",
    y="Pct_Increase"
)

plt.title("Impact of Oil Import Dependency on Petrol Prices")

plt.show()

# %%
prices.groupby("Oil_Import_Dep")["Pct_Increase"].mean()
# Out:
# Oil_Import_Dep
# High      4.7575
# Low       5.9050
# Medium    3.8900
# Name: Pct_Increase, dtype: float64

# %%
corr = prices.select_dtypes(include=np.number).corr()

plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")

plt.show()

# %%
print(impact.columns)
# Out:
# Index(['Country', 'Region', 'Oil_Import_Pct', 'GDP_Impact_Pct',
#        'Inflation_Risk', 'Stock_Market_Change', 'Currency_Pressure',
#        'Policy_Response', 'Vulnerability', 'Population_M'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=impact,
    x="GDP_Impact_Pct",
    y="Inflation_Risk",
    hue="Region"
)

plt.title("GDP Impact vs Inflation Risk")

plt.show()

# %%
model = ARIMA(
    crude["Brent_USD"],
    order=(1,1,1)
)

model_fit = model.fit()

forecast = model_fit.forecast(steps=5)

print("Next 5 Day Brent Oil Price Forecast")
print(forecast)
# Out:
# Next 5 Day Brent Oil Price Forecast
# 16    109.531782
# 17    114.630658
# 18    119.552962
# 19    124.304809
# 20    128.892101
# Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.plot(
    crude["Brent_USD"],
    label="Actual"
)

plt.plot(
    range(len(crude), len(crude)+5),
    forecast,
    label="Forecast"
)

plt.title("Brent Oil Price Forecast")
plt.legend()

plt.show()

# %%
timeline.head(10)
# Out:
#          Date                    Event  \
# 0  2025-12-01                 Protests
# 1  2025-12-15        Internet Shutdown
# 2  2026-01-10      US Military Buildup
# 3  2026-02-01       Geneva Talks Begin
# 4  2026-02-25           Talks Collapse
# 5  2026-02-28   Military Strikes Begin
# 6  2026-03-01  Strait of Hormuz Closed
# 7  2026-03-01         Mojtaba Khamenei
# 8  2026-03-02               Oil Spikes
# 9  2026-03-03             Risk Premium
#
#                                          Description          Location  \
# 0  Widespread economic protests erupt across Iran...              Iran
# 1  Iran government shuts down internet amid crack...              Iran
# 2  US bolsters military presence off Iran's coast...        USA / Iran
# 3  Indirect US-Iran nuclear negotiations begin in...       Switzerland
# 4  Geneva nuclear negotiations end without breakt...       Switzerland
# 5  US-Israeli military strikes commence against I...              Iran
# 6  Iran retaliates by closing Strait of Hormuz — ...  Strait of Hormuz
# 7  Mojtaba Khamenei selected as new Supreme Leade...              Iran
# 8  Brent crude surges past $85/barrel; WTI jumps ...            Global
# 9  Goldman Sachs: traders demand additional $14/b...            Global
#
#           Category
# 0        Political
# 1        Political
# 2         Military
# 3       Diplomatic
# 4       Diplomatic
# 5         Military
# 6  Military/Energy
# 7        Political
# 8         Economic
# 9         Economic

# %%
from scipy.stats import ttest_ind

high_dep = prices[prices["Oil_Import_Dep"]=="High"]["Pct_Increase"]
low_dep = prices[prices["Oil_Import_Dep"]=="Low"]["Pct_Increase"]

ttest_ind(high_dep, low_dep)
# Out:
# TtestResult(statistic=np.float64(-0.33145517847463607), pvalue=np.float64(0.7471422349951589), df=np.float64(10.0))

# %%
prices["Price_Change"] = prices["Mar7_USD"] - prices["Before_War_USD"]

crude["Brent_Return"] = crude["Brent_USD"].pct_change()
crude["WTI_Return"] = crude["WTI_USD"].pct_change()

# %%
fig = px.choropleth(
    prices,
    locations="ISO",
    color="Pct_Increase",
    hover_name="Country",
    title="Global Petrol Price Increase"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc8acb13-6ebd-417d-bb6c-c89b442bdfe5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc8acb13-6ebd-417d-bb6c-c89b442bdfe5")) {                    Plotly.newPlot(                        "dc8acb13-6ebd-417d-bb6c-c89b442bdfe5",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eISO=%{location}\u003cbr\u003ePct_Increase=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Pakistan","India","Bangladesh","Afghanistan","Nepal","Sri Lanka","Turkey","Iran","Saudi Arabia","UAE","China","United Kingdom","Germany","USA"],"locations":["PAK","IND","BGD","AFG","NPL","LKA","TUR","IRN","SAU","ARE","CHN","GBR","DEU","USA"],"name":"","z":[20.66,0.0,4.0,0.0,2.15,1.37,4.88,6.67,6.45,4.62,5.0,3.93,3.85,5.88],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"mark ...

# %% [markdown]
# **Key Findings**
#
# * Oil prices increased over 50% during the conflict
# * Oil-import dependent countries experienced 15–20% higher petrol price increases
# * Developing economies face greater inflation risk
# * Energy diversification could reduce future shocks
